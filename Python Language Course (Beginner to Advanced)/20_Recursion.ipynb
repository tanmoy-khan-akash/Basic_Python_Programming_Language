# %% [markdown]
# ### **Python Function Recursion**

# %%
# 5! = 5 * 4 * 3 * 2 * 1 = 120

def factor(x):
  if x == 0:
    return 1
  return x* factor(x-1)

# %%
factor(5)
# Out:
# 120

# %%
def web():
  print('linktr.ee')
web()
# Out:
# linktr.ee

# %%
# VS code

def web():
  print('linktr.ee')
  web()
web()
