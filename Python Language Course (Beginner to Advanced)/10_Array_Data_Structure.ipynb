# %% [markdown]
# ### Python Array

# %%
from IPython.display import Image
Image('Array.png')

# %% [markdown]
# ### Array Methods

# %%
from IPython.display import Image
Image('Array Methods.png')

# %%
import array as ar

# %%
ar1 = ar.array('i', [1,2,3,5,10])
ar1
# Out:
# array('i', [1, 2, 3, 5, 10])

# %%
ar1 = ar.array('f', [1,2,3,5,10.5])
ar1
# Out:
# array('f', [1.0, 2.0, 3.0, 5.0, 10.5])

# %%
ar1[0]
# Out:
# 1.0

# %%
ar1[0] = 15   #changeable
ar1
# Out:
# array('f', [15.0, 2.0, 3.0, 5.0, 10.5])

# %%
ar1[2:4]
# Out:
# array('f', [3.0, 5.0])

# %%
ar1.append(8)
ar1
# Out:
# array('f', [15.0, 2.0, 3.0, 5.0, 10.5, 8.0])

# %%
del ar1[-1]
ar1
# Out:
# array('f', [15.0, 2.0, 3.0, 5.0, 10.5])

# %%
len(ar1)
# Out:
# 5

# %%
ar1.reverse()
ar1
# Out:
# array('f', [10.5, 5.0, 3.0, 2.0, 15.0])

# %%
ar1.count(5)
# Out:
# 1

# %%
ar1.index(10.5)
# Out:
# 0

# %%
ar1.pop(3)   # 3 is index no
ar1
# Out:
# array('f', [1.0, 2.0, 3.0, 10.5])

# %%
ar1.remove(3)
ar1
# Out:
# array('f', [1.0, 2.0, 10.5])

# %%
r = ar.array('i', [])

items = int(input())
for i in range(items):
    val = int(input())
    r.append(val)
print(r)
# Out:
#  3
#  12
#  15
#  20
# array('i', [12, 15, 20])

# %%
r = ar.array('f', [])

items = int(input())
for i in range(items):
    val = int(input())
    r.append(val)
print(r)
# Out:
#  2
#  5
#  10
# array('f', [5.0, 10.0])
