# %% [markdown]
# ### Python Dictionary

# %%
from IPython.display import Image
Image('Dictionary.png')

# %%
from IPython.display import Image
Image('Dictionary Example.png')

# %%
dic = {
    'name': 'Tanmoy Khan',
    'university': 'WUB'
}
dic
# Out:
# {'name': 'Tanmoy Khan', 'university': 'WUB'}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'university'])

# %%
type(dic)
# Out:
# dict

# %%
dic.values()
# Out:
# dict_values(['Tanmoy Khan', 'WUB'])

# %%
# copy

dic2 = dic.copy()
dic2
# Out:
# {'name': 'Tanmoy Khan', 'university': 'WUB'}

# %%
dic['university'] = 'NSU'
dic
# Out:
# {'name': 'Tanmoy Khan', 'university': 'NSU'}

# %%
dic['dept'] = 'Data Science'
dic
# Out:
# {'name': 'Tanmoy Khan', 'university': 'NSU', 'dept': 'Data Science'}

# %%
# update

dic.update({'dept': 'Ai'})
dic
# Out:
# {'name': 'Tanmoy Khan', 'university': 'NSU', 'dept': 'Ai'}

# %%
# pop

dic.popitem()
dic
# Out:
# {'name': 'Tanmoy Khan', 'university': 'NSU'}

# %%
dic.pop('university')
# Out:
# 'NSU'

# %%
dic
# Out:
# {'name': 'Tanmoy Khan'}

# %%
dic['dept'] = 'Data Science'
dic
# Out:
# {'name': 'Tanmoy Khan', 'dept': 'Data Science'}

# %%
del dic['name']
dic
# Out:
# {'dept': 'Data Science'}

# %%
dic['dept2'] = 'ML'
dic
# Out:
# {'dept': 'Data Science', 'dept2': 'ML'}

# %%
# print all items

for x in dic:
    print(dic[x])   # show value
# Out:
# Data Science
# ML

# %%
for x in dic:
    print(x)   # show key
# Out:
# dept
# dept2

# %%
d2 = list(dic.keys())
d2
# Out:
# ['dept', 'dept2']

# %%
d3 = list(dic.values())
d3
# Out:
# ['Data Science', 'ML']

# %%
# dic from user input

n = int(input())
d = {}

for i in range(n):
    key = input()
    value = input()
    d[key] = value
print(d)
# Out:
#  3
#  name
#  tanmoy
#  dept
#  data science
#  dept2
#  NLP
# {'name': 'tanmoy', 'dept': 'data science', 'dept2': 'NLP'}

# %%
d
# Out:
# {'name': 'tanmoy', 'dept': 'data science', 'dept2': 'NLP'}
