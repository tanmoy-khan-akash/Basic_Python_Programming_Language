# %% [markdown]
# ### **Functions in Python**

# %%
from IPython.display import Image
Image('Function.png')

# %%
from IPython.display import Image
Image('Function Example.png')

# %% [markdown]
# #### **1. Function Definition:**
#
# #### To define a function, use the def keyword followed by the function name and parentheses. For example:

# %%
def dept():
  print('Data Science!')

# %% [markdown]
# #### **2. Function Call:**
#
# #### To execute a function, call it by using its name followed by parentheses:

# %%
dept()
# Out:
# Data Science!

# %% [markdown]
# #### **3. Parameters:**
#
# #### Function can accept parameters(inputs). Parameters are variables that are used as placeholders for the actual values when the function is called.

# %%
def dept_names(name):
  print(f'My major is {name}')

# %%
dept_names('Machine learning & AI')
# Out:
# My major is Machine learning & AI

# %% [markdown]
# #### **4. Return Statement:**
#
# #### Function can return a value using the "return" statement. This is useful when you want to use the result of a function else where in your code.

# %%
def name():
  print('Bangladesh')
  return 1

# %%
name()
# Out:
# Bangladesh
# 1

# %%
# Or

def names():
  return print('Gopalganj')

# %%
names()
# Out:
# Gopalganj

# %%
def names():
  return name()

# %%
names()
# Out:
# Bangladesh
# 1

# %% [markdown]
# #### **Question_01:**

# %% [markdown]
# #### Write a function that wont take any parameters explicitly. Instead, it defines local variables a and b within the function and returns their sum. The values of a and b are fixed within the function.

# %%
def add_num():
  a = 10
  b = 20
  return a + b

# %%
add_num()
# Out:
# 30

# %%
# Or

def add_num():
  a = 10
  b = 20
  result = a + b
  return result

add_num()
# Out:
# 30

# %% [markdown]
# #### **Question_02:**

# %% [markdown]
# #### Write a function that will take two parameters, a and b, and returns their sum. The values of a and b will not fixed within the function; they are determined by the arguments passed when the function is called. That will make the function more flexible because it can add any two numbers, not just the fixed values in the first function.

# %%
def add_num(a, b):
  result = a + b
  return result

add_num(25, 50)
# Out:
# 75

# %%
add_num(10, 25)
# Out:
# 35

# %% [markdown]
# #### The key difference lies in the flexibility and reusability of the second function, which can add any two numbers based on the arguments provided, while the first function is limited to adding the fixed values a and b.

# %%
def user_input():
  x1 = int(input())
  x2 = int(input())
  y1 = int(input())
  y2= int(input())

  return x1, x2

user_input()
# Out:
# 1
# 2
# 3
# 4
# (1, 2)

# %%
def user_input():
  x1 = int(input())
  x2 = int(input())
  y1 = int(input())
  y2= int(input())

  return x1, x2, y1, y2

user_input()
# Out:
# 1
# 3
# 2
# 4
# (1, 3, 2, 4)

# %%
def user_input():
  x1 = int(input())
  x2 = int(input())
  y1 = int(input())
  y2= int(input())

  return x1, y1, x2, y2

user_input()
# Out:
# 1
# 3
# 2
# 4
# (1, 2, 3, 4)

# %%
def user_input():
  x1 = int(input())
  x2 = int(input())
  y1 = int(input())
  y2= int(input())

  return (x1, y1), (x2, y2)

user_input()
# Out:
# 1
# 2
# 3
# 4
# ((1, 3), (2, 4))

# %%
def user_input():
  x1 = int(input())
  x2 = int(input())
  y1 = int(input())
  y2= int(input())

  return (x1, y1), (x2, y2)

r1, r2 = user_input()
# Out:
# 1
# 2
# 3
# 4

# %%
r1
# Out:
# (1, 3)

# %%
r2
# Out:
# (2, 4)

# %%
def user_input():
  x1 = int(input())
  x2 = int(input())
  y1 = int(input())
  y2= int(input())

  return (x1, y1), (x2, y2)

r1, _ = user_input()
# Out:
# 1
# 2
# 3
# 4

# %%
r1
# Out:
# (1, 3)

# %%
r1 = user_input()
# Out:
# 1
# 2
# 3
# 4

# %%
def sq_and_cube(x):
  sq = x**2
  cube = x**3
  return sq, cube

sq_and_cube(3)
# Out:
# (9, 27)

# %% [markdown]
# #### How to use a function inside another function?

# %%
def mulp():
  x = int(input('x = '))
  y = int(input('y = '))
  result = x * y
  print(result)

mulp()
# Out:
# x = 10
# y = 20
# 200

# %%
def mulp1():
  x = int(input('x = '))
  y = int(input('y = '))
  result = x * y
  print('result: ', result)
  return result

def mulp2():
  total_1 = mulp1()
  z = int(input('z = '))
  total_2 = total_1 * z
  print('Final result = ', total_2)

# %%
mulp2()
# Out:
# x =  10
# y =  2
# result:  20
# z =  5
# Final result =  100
