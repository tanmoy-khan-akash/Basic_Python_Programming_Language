# %% [markdown]
# ### **Module in Python**

# %%
# %%writefile test_module.py    ## This line is not needed if coding in PyCharm / VS Code.
#
# def greet(name):
#   print(f'Hello, {name}!')
#
# def square(x):
#   return x**2
# Out:
# Writing test_module.py

# %% [markdown]
# #### **In Jupyter Notebook / PyCharm / VScode need to create (22) and (22.1) these two files.**
