# %% [markdown]
# ### **In Jupyter Notebook / PyCharm / VScode need to create (22) and (22.1) these two files.**

# %%
import test_module

test_module.greet('Tanmoy Khan Akash')
test_module.square(10)
# Out:
# Hello, Tanmoy Khan Akash!
# 100

# %%
from test_module import greet

greet('Tanmoy Khan Akash')
# test_module.square(10)
# Out:
# Hello, Tanmoy Khan Akash!

# %%
from test_module import greet, square

greet('Tanmoy Khan Akash')
square(10)
# Out:
# Hello, Tanmoy Khan Akash!
# 100

# %%
from test_module import *

greet('Tanmoy Khan Akash')
square(10)
# Out:
# Hello, Tanmoy Khan Akash!
# 100
